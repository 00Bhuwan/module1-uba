# %%
import numpy as np
import pandas as pd
# import missingno as msn

# %%
df = pd.read_csv('IMDbMovies.csv')

# %%
df.head()
# Out:
#                                                Title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
#
#                                              Summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
#
#                                             Director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
#
#                                           Writer                 Main Genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
#
#   Motion Picture Rating Runtime  Release Year  Rating Number of Ratings  \
# 0                     R  2h 38m        2023.0  6.7/10               38K
# 1                 PG-13  2h 37m        2023.0  7.2/10               37K
# 2                     R  1h 58m        2023.0  6.8/10              117K
# 3                    PG  1h 42m        2023.0  7.0/10               10K
# 4                     R  1h 46m        2023.0  7.0/10              9.1K
#
#                      Budget Gross in US & Canada Gross worldwide  \
# 0                       NaN         $37,514,498     $84,968,381
# 1  $100,000,000 (estimated)        $105,043,414    $191,729,235
# 2                       NaN                  NaN       $421,332
# 3                       NaN                  NaN             NaN
# 4                       NaN         $25,408,677     $29,666,585
#
#   Opening Weekend Gross in US & Canada
# 0              $20,638,887Nov 26, 2023
# 1              $44,607,143Nov 19, 2023
# 2                                  NaN
# 3                                  NaN
# 4              $10,306,272Nov 19, 2023

# %%
df.shape
# Out:
# (9083, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Title                                 9083 non-null   object
#  1   Summary                               9083 non-null   object
#  2   Director                              9052 non-null   object
#  3   Writer                                8759 non-null   object
#  4   Main Genres                           9076 non-null   object
#  5   Motion Picture Rating                 8285 non-null   object
#  6   Runtime                               8918 non-null   object
#  7   Release Year                          9076 non-null   float64
#  8   Rating                                8813 non-null   object
#  9   Number of Ratings                     8813 non-null   object
#  10  Budget                                5879 non-null   object
#  11  Gross in US & Canada                  6064 non-null   object
#  12  Gross worldwide                       7128 non-null   object
#  13  Opening Weekend Gross in US & Canada  5695 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 993.6+ KB

# %%
df.describe().T
# Out:
#                count         mean        std     min     25%     50%     75%  \
# Release Year  9076.0  2004.142133  18.849816  1915.0  1994.0  2010.0  2019.0
#
#                  max
# Release Year  2027.0

# %%
df.sample(5)
# Out:
#                         Title  \
# 6710                   Nobody
# 6793      Our Kind of Traitor
# 4462                   Sirona
# 7232  The Center of the World
# 7730               White Fang
#
#                                                 Summary         Director  \
# 6710  A docile family man slowly reveals his true ch...  Ilya Naishuller
# 6793  A couple finds themselves lured into a Russian...    Susanna White
# 4462  A young woman with supernatural gifts escapes ...     Wesley Clark
# 7232  A successful computer engineer meets a strippe...       Wayne Wang
# 7730  Jack London's classic adventure story about th...   Randal Kleiser
#
#                                        Writer             Main Genres  \
# 6710                            Derek Kolstad      Action,Crime,Drama
# 6793              Hossein Amini,John le Carré      Action,Crime,Drama
# 4462                             Wesley Clark          Mystery,Sci-Fi
# 7232      Paul Auster,Miranda July,Wayne Wang           Drama,Romance
# 7730  Nick Thiel,Jack London,Jeanne Rosenberg  Adventure,Drama,Family
#
#      Motion Picture Rating Runtime  Release Year  Rating Number of Ratings  \
# 6710                     R  1h 32m        2021.0  7.4/10              310K
# 6793                     R  1h 48m        2016.0  6.2/10               23K
# 4462                   NaN  1h 40m        2023.0  3.7/10               167
# 7232               Unrated  1h 28m        2001.0  5.8/10              5.2K
# 7730                    PG  1h 47m        1991.0  6.7/10               22K
#
#                        Budget Gross in US & Canada Gross worldwide  \
# 6710  $16,000,000 (estimated)         $27,568,035     $57,510,518
# 6793                      NaN          $3,153,157     $10,711,027
# 4462      $70,000 (estimated)                  NaN             NaN
# 7232                      NaN          $1,101,344      $1,460,687
# 7730  $14,000,000 (estimated)         $34,793,160     $34,793,160
#
#      Opening Weekend Gross in US & Canada
# 6710               $6,820,100Mar 28, 2021
# 6793                  $984,698Jul 3, 2016
# 4462                                  NaN
# 7232                  $67,809Apr 22, 2001
# 7730               $5,640,712Jan 21, 1991

# %%
# missing values

df.isnull().sum()
# Out:
# Title                                      0
# Summary                                    0
# Director                                  31
# Writer                                   324
# Main Genres                                7
# Motion Picture Rating                    798
# Runtime                                  165
# Release Year                               7
# Rating                                   270
# Number of Ratings                        270
# Budget                                  3204
# Gross in US & Canada                    3019
# Gross worldwide                         1955
# Opening Weekend Gross in US & Canada    3388
# dtype: int64

# %%
# duplicated

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# missingno library to visualize missing values. If there are missing values in different columns you can see easily if there is a relationship between missing values or not.
# msn.matrix(df)

# %%
df.head()
# Out:
#                                                Title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
#
#                                              Summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
#
#                                             Director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
#
#                                           Writer                 Main Genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
#
#   Motion Picture Rating Runtime  Release Year  Rating Number of Ratings  \
# 0                     R  2h 38m        2023.0  6.7/10               38K
# 1                 PG-13  2h 37m        2023.0  7.2/10               37K
# 2                     R  1h 58m        2023.0  6.8/10              117K
# 3                    PG  1h 42m        2023.0  7.0/10               10K
# 4                     R  1h 46m        2023.0  7.0/10              9.1K
#
#                      Budget Gross in US & Canada Gross worldwide  \
# 0                       NaN         $37,514,498     $84,968,381
# 1  $100,000,000 (estimated)        $105,043,414    $191,729,235
# 2                       NaN                  NaN       $421,332
# 3                       NaN                  NaN             NaN
# 4                       NaN         $25,408,677     $29,666,585
#
#   Opening Weekend Gross in US & Canada
# 0              $20,638,887Nov 26, 2023
# 1              $44,607,143Nov 19, 2023
# 2                                  NaN
# 3                                  NaN
# 4              $10,306,272Nov 19, 2023

# %%
missing = df.isna().sum().sum()
# total = np.prod(df.shape)
total = 9083*14
print("percentage missing is ", missing/total * 100)
# Out:
# percentage missing is  10.567622402919111

# %%
df["Opening Weekend Gross in US & Canada"].isna().sum()/9083 *100
# Out:
# np.float64(37.30045139271166)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Title                                 9083 non-null   object
#  1   Summary                               9083 non-null   object
#  2   Director                              9052 non-null   object
#  3   Writer                                8759 non-null   object
#  4   Main Genres                           9076 non-null   object
#  5   Motion Picture Rating                 8285 non-null   object
#  6   Runtime                               8918 non-null   object
#  7   Release Year                          9076 non-null   float64
#  8   Rating                                8813 non-null   object
#  9   Number of Ratings                     8813 non-null   object
#  10  Budget                                5879 non-null   object
#  11  Gross in US & Canada                  6064 non-null   object
#  12  Gross worldwide                       7128 non-null   object
#  13  Opening Weekend Gross in US & Canada  5695 non-null   object
# dtypes: float64(1), object(13)
# memory usage: 993.6+ KB

# %%
# runtime, rating, no of rating is obj can be change to int or float for easy analysis
# column gross in us & canada and opening weekend gross in us & canada is missing nearly 40% of total data so dropping them.

removed_df = df[['Gross in US & Canada', 'Opening Weekend Gross in US & Canada']]

df = df.drop(columns=['Gross in US & Canada', 'Opening Weekend Gross in US & Canada'], axis=1)

# %%
df['Runtime'] = df["Runtime"].str.extract(r'(?:(\d+)h)?\s*(?:(\d+)m)?').astype(float).dot([60,1])

# %%
df = df.rename(columns={"Runtime": 'runtime_min'})

# %%
df.columns
# Out:
# Index(['Title', 'Summary', 'Director', 'Writer', 'Main Genres',
#        'Motion Picture Rating', 'runtime_min', 'Release Year', 'Rating',
#        'Number of Ratings', 'Budget', 'Gross worldwide'],
#       dtype='object')

# %%
df['Rating'][5:10]
# Out:
# 5    8.5/10
# 6    7.5/10
# 7    6.0/10
# 8    5.9/10
# 9    6.9/10
# Name: Rating, dtype: object

# %%
df["Rating"] = df['Rating'].str.extract(r'(\d+)/10').astype(float)
df = df.rename(columns={"Rating": "rating_outof_10"})

# %%
df['rating_outof_10'].isna().sum()
# Out:
# np.int64(271)

# %%
df.head(5)
# Out:
#                                                Title  \
# 0                                           Napoleon
# 1  The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                         The Killer
# 3                                                Leo
# 4                                       Thanksgiving
#
#                                              Summary  \
# 0  An epic that details the checkered rise and fa...
# 1  Coriolanus Snow mentors and develops feelings ...
# 2  After a fateful near-miss, an assassin battles...
# 3  A 74-year-old lizard named Leo and his turtle ...
# 4  After a Black Friday riot ends in tragedy, a m...
#
#                                             Director  \
# 0                                       Ridley Scott
# 1                                   Francis Lawrence
# 2                                      David Fincher
# 3  David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                           Eli Roth
#
#                                           Writer                 Main Genres  \
# 0                                   David Scarpa  Action,Adventure,Biography
# 1  Michael Lesslie,Michael Arndt,Suzanne Collins      Action,Adventure,Drama
# 2  Andrew Kevin Walker,Luc Jacamon,Alexis Nolent      Action,Adventure,Crime
# 3           Paul Sado,Robert Smigel,Adam Sandler     Animation,Comedy,Family
# 4                          Eli Roth,Jeff Rendell     Horror,Mystery,Thriller
#
#   Motion Picture Rating  runtime_min  Release Year  rating_outof_10  \
# 0                     R        158.0        2023.0              7.0
# 1                 PG-13        157.0        2023.0              2.0
# 2                     R        118.0        2023.0              8.0
# 3                    PG        102.0        2023.0              0.0
# 4                     R        106.0        2023.0              0.0
#
#   Number of Ratings                    Budget Gross worldwide
# 0               38K                       NaN    $84,968,381
# 1               37K  $100,000,000 (estimated)   $191,729,235
# 2              117K                       NaN       $421,332
# 3               10K                       NaN             NaN
# 4              9.1K                       NaN    $29,666,585

# %%
counts = df['Number of Ratings'].str.extract(r'(\d+\.?\d*)([KM]?)')

# %%
pd.unique(counts[1])
# Out:
# array(['K', nan, 'M', ''], dtype=object)

# %%
df['Number of Ratings'] = (counts[0].astype(float) * counts[1].map({'K': 1000, "M": 1000000, '':1}))

# %%
df = df.rename(columns={'Number of Ratings': 'no_of_rating'})

# %%
print(df['no_of_rating'].isnull().sum())
df = df.fillna({'Budget': 0})
# Out:
# 270

# %%
df['Budget'].isnull().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#                                                   Title  \
# 0                                              Napoleon
# 1     The Hunger Games: The Ballad of Songbirds & Sn...
# 2                                            The Killer
# 3                                                   Leo
# 4                                          Thanksgiving
# ...                                                 ...
# 9078                                      Over the Moon
# 9079                                         Young Adam
# 9080                         The Greatest Show on Earth
# 9081                                         Deep Water
# 9082                       Once Upon a Time in Anatolia
#
#                                                 Summary  \
# 0     An epic that details the checkered rise and fa...
# 1     Coriolanus Snow mentors and develops feelings ...
# 2     After a fateful near-miss, an assassin battles...
# 3     A 74-year-old lizard named Leo and his turtle ...
# 4     After a Black Friday riot ends in tragedy, a m...
# ...                                                 ...
# 9078  In this animated musical, a girl builds a rock...
# 9079  A young drifter working on a river barge disru...
# 9080  The dramatic lives of trapeze artists, a clown...
# 9081  A group of international passengers en route f...
# 9082  A group of men set out in search of a dead bod...
#
#                                                Director  \
# 0                                          Ridley Scott
# 1                                      Francis Lawrence
# 2                                         David Fincher
# 3     David Wachtenheim,Robert Smigel,Robert Marianetti
# 4                                              Eli Roth
# ...                                                 ...
# 9078                              John Kahrs,Glen Keane
# 9079                                    David Mackenzie
# 9080                                   Cecil B. DeMille
# 9081                                       Renny Harlin
# 9082                                  Nuri Bilge Ceylan
#
#                                                Writer  \
# 0                                        David Scarpa
# 1       Michael Lesslie,Michael Arndt,Suzanne Collins
# 2       Andrew Kevin Walker,Luc Jacamon,Alexis Nolent
# 3                Paul Sado,Robert Smigel,Adam Sandler
# 4                               Eli Roth,Jeff Rendell
# ...                                               ...
# 9078      Jennifer Yee McDevitt,Audrey Wells,Alice Wu
# 9079                Alexander Trocchi,David Mackenzie
# 9080  Theodore St. John,Fredric M. Frank,Barré Lyndon
# 9081                                     Pete Bridges
# 9082        Ercan Kesal,Nuri Bilge Ceylan,Ebru Ceylan
#
#                      Main Genres Motion Picture Rating  runtime_min  \
# 0     Action,Adventure,Biography                     R        158.0
# 1         Action,Adventure,Drama                 PG-13        157.0
# 2         Action,Adventure,Crime                     R        118.0
# 3        Animation,Comedy,Family                    PG        102.0
# 4        Horror,Mystery,Thriller                     R        106.0
# ...                          ...                   ...          ...
# 9078  Animation,Adventure,Comedy                    PG         95.0
# 9079                 Crime,Drama                 NC-17         98.0
# 9080        Drama,Family,Romance                Passed        152.0
# 9081                    Thriller                Passed        152.0
# 9082        Crime,Drama,Thriller             Not Rated        157.0
#
#       Release Year  rating_outof_10  no_of_rating                    Budget  \
# 0           2023.0              7.0       38000.0                         0
# 1           2023.0              2.0       37000.0  $100,000,000 (estimated)
# 2           2023.0              8.0      117000.0                         0
# 3           2023.0              0.0       10000.0                         0
# 4           2023.0              0.0        9100.0                         0
# ...            ...              ...           ...                       ...
# 9078        2020.0              3.0       24000.0                         0
# 9079        2003.0              4.0       15000.0    $6,400,000 (estimated)
# 9080        1952.0              5.0       16000.0    $4,000,000 (estimated)
# 9081        1952.0              NaN           NaN                         0
# 9082        2011.0              8.0       49000.0                         0
#
#      Gross worldwide
# 0       $84,968,381
# 1      $191,729,235
# 2          $421,332
# 3                NaN
# 4       $29,666,585
# ...              ...
# 9078             NaN
# 9079     $2,561,820
# 9080    $36,000,000
# 9081             NaN
# 9082     $2,099,472
#
# [9083 rows x 12 columns]

# %%
df['Budget'] = (df['Budget'].str.replace(r'[^\d]', '', regex=True).astype(float))

# %%
pd.unique(df['Gross worldwide'])
# Out:
# array(['$84,968,381 ', '$191,729,235 ', '$421,332 ', ..., '$2,561,820 ',
#        '$36,000,000 ', '$2,099,472 '], shape=(7118,), dtype=object)

# %%
df['Gross worldwide'] = (df['Gross worldwide'].str.replace(r'[^\d]', '', regex=True).astype(float))

# %%
df.isnull().sum()
# Out:
# Title                       0
# Summary                     0
# Director                   31
# Writer                    324
# Main Genres                 7
# Motion Picture Rating     798
# runtime_min               310
# Release Year                7
# rating_outof_10           271
# no_of_rating              270
# Budget                   3204
# Gross worldwide          1955
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9083 non-null   object
#  1   Summary                9083 non-null   object
#  2   Director               9052 non-null   object
#  3   Writer                 8759 non-null   object
#  4   Main Genres            9076 non-null   object
#  5   Motion Picture Rating  8285 non-null   object
#  6   runtime_min            8773 non-null   float64
#  7   Release Year           9076 non-null   float64
#  8   rating_outof_10        8812 non-null   float64
#  9   no_of_rating           8813 non-null   float64
#  10  Budget                 5879 non-null   float64
#  11  Gross worldwide        7128 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 851.7+ KB

# %%
df['Director'] = df['Director'].fillna('Unknown')
df['Writer'] = df['Writer'].fillna('Unknown')
df['Motion Picture Rating'] = df['Motion Picture Rating'].fillna('Unrated')
df['runtime_min'] = df['runtime_min'].fillna(df['runtime_min'].median())
df['rating_outof_10'] = df['rating_outof_10'].fillna(df['rating_outof_10'].median())

# %%
df_budget = df.dropna(subset=['Budget', 'Gross worldwide'])

# %%
df.isnull().sum()
# Out:
# Title                       0
# Summary                     0
# Director                    0
# Writer                      0
# Main Genres                 7
# Motion Picture Rating       0
# runtime_min                 0
# Release Year                7
# rating_outof_10             0
# no_of_rating              270
# Budget                   3204
# Gross worldwide          1955
# dtype: int64

# %%
df.sort_values('rating_outof_10', ascending=False)
# Out:
#                            Title  \
# 7330                      Domino
# 9                    The Creator
# 9054                  The Return
# 8                           Wish
# 55             Anatomy of a Fall
# ...                          ...
# 9067                  The Escort
# 19                        Barbie
# 13                   Blue Beetle
# 11          Trolls Band Together
# 10    Killers of the Flower Moon
#
#                                                 Summary  \
# 7330  A recounting of Domino Harvey's life story. Th...
# 9     Against the backdrop of a war between humans a...
# 9054  In the Russian wilderness, two brothers face a...
# 8     A young girl named Asha wishes on a star and g...
# 55    A woman is suspected of her husband's murder, ...
# ...                                                 ...
# 9067  Desperate for a good story, a sex-addicted jou...
# 19    Barbie suffers a crisis that leads her to ques...
# 13    An alien scarab chooses Jaime Reyes to be its ...
# 11    Poppy discovers that Branch was once part of t...
# 10    When oil is discovered in 1920s Oklahoma under...
#
#                            Director  \
# 7330                     Tony Scott
# 9                    Gareth Edwards
# 9054             Andrey Zvyagintsev
# 8     Fawn Veerasunthorn,Chris Buck
# 55                    Justine Triet
# ...                             ...
# 9067                  Will Slocombe
# 19                     Greta Gerwig
# 13                Angel Manuel Soto
# 11             Walt Dohrn,Tim Heitz
# 10                  Martin Scorsese
#
#                                                Writer  \
# 7330                     Richard Kelly,Steve Barancik
# 9                          Chris Weitz,Gareth Edwards
# 9054  Aleksandr Novototskiy-Vlasov,Vladimir Moiseenko
# 8               Jennifer Lee,Chris Buck,Allison Moore
# 55                        Arthur Harari,Justine Triet
# ...                                               ...
# 9067                    Brandon Cohen,Michael Doneger
# 19                         Greta Gerwig,Noah Baumbach
# 13                              Gareth Dunnet-Alcocer
# 11           Kim Caramele,Thomas Dam,Elizabeth Tippet
# 10              Eric Roth,David Grann,Martin Scorsese
#
#                      Main Genres Motion Picture Rating  runtime_min  \
# 7330      Action,Biography,Crime                     R        127.0
# 9         Action,Adventure,Drama                 PG-13        133.0
# 9054                       Drama             Not Rated        110.0
# 8     Animation,Adventure,Comedy                    PG         95.0
# 55          Crime,Drama,Thriller                     R        151.0
# ...                          ...                   ...          ...
# 9067        Comedy,Drama,Romance             Not Rated         88.0
# 19      Adventure,Comedy,Fantasy                 PG-13        114.0
# 13       Action,Adventure,Sci-Fi                 PG-13        127.0
# 11    Animation,Adventure,Comedy                    PG         91.0
# 10           Crime,Drama,History                     R        206.0
#
#       Release Year  rating_outof_10  no_of_rating       Budget  \
# 7330        2005.0              9.0       69000.0   50000000.0
# 9           2023.0              9.0       79000.0   80000000.0
# 9054        2003.0              9.0       47000.0          NaN
# 8           2023.0              9.0        6400.0  200000000.0
# 55          2023.0              9.0       17000.0    6200000.0
# ...            ...              ...           ...          ...
# 9067        2015.0              0.0       14000.0          NaN
# 19          2023.0              0.0      393000.0  100000000.0
# 13          2023.0              0.0       72000.0  104000000.0
# 11          2023.0              0.0        5200.0          NaN
# 10          2023.0              0.0       97000.0  200000000.0
#
#       Gross worldwide
# 7330     2.298463e+07
# 9        1.041810e+08
# 9054     8.482993e+06
# 8        5.127605e+07
# 55       1.822126e+07
# ...               ...
# 9067              NaN
# 19       1.441792e+09
# 13       1.292881e+08
# 11       1.497628e+08
# 10       1.521787e+08
#
# [9083 rows x 12 columns]

# %%
'''
IMDb Movies Dataset
What you can do:

Highest rated movies by genre
Trends over years
Director and actor analysis
Rating vs revenue
'''
# Out:
# '\nIMDb Movies Dataset\nWhat you can do:\n\nHighest rated movies by genre\nTrends over years\nDirector and actor analysis\nRating vs revenue\n'

# %%
genres = ['Comedy', 'Adventure', 'Crime', 'Drama', 'Action', 'History']
for genre in genres:
    count = df[
        (df['rating_outof_10'] == 9.0) &
        (df['Main Genres'].str.contains(genre, case=False, na=False))
    ].shape[0]

    print(f"For {genre}: {count}")
# Out:
# For Comedy: 269
# For Adventure: 145
# For Crime: 126
# For Drama: 387
# For Action: 180
# For History: 25

# %%
genres = ['Comedy', 'Adventure', 'Crime', 'Drama', 'Action', 'History']
for year in range(2020, 2023):
    print('\n year: ', year)
    for genre in genres:
        count = df[
            (df['Release Year'] == year) &
            (df['Main Genres'].str.contains(genre, case=False, na=False))
        ].shape[0]
        
        print(f"For {genre}: {count}")
# Out:
#  year:  2020
# For Comedy: 83
# For Adventure: 40
# For Crime: 32
# For Drama: 145
# For Action: 55
# For History: 12
#
#  year:  2021
# For Comedy: 87
# For Adventure: 60
# For Crime: 60
# For Drama: 196
# For Action: 91
# For History: 14
#
#  year:  2022
# For Comedy: 171
# For Adventure: 78
# For Crime: 73
# For Drama: 293
# For Action: 112
# For History: 20

# %%
print(df.info())
print(df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9083 non-null   object
#  1   Summary                9083 non-null   object
#  2   Director               9083 non-null   object
#  3   Writer                 9083 non-null   object
#  4   Main Genres            9076 non-null   object
#  5   Motion Picture Rating  9083 non-null   object
#  6   runtime_min            9083 non-null   float64
#  7   Release Year           9076 non-null   float64
#  8   rating_outof_10        9083 non-null   float64
#  9   no_of_rating           8813 non-null   float64
#  10  Budget                 5879 non-null   float64
#  11  Gross worldwide        7128 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 851.7+ KB
# None
# (9083, 12)

# %%
df_new = df.copy(["Director","Writer", "Rating", "Number of Ratings"])   # doesn't work : copies whole df not specific column
# df_new = df[[column]].copy()               # works as intended

# %%
del(df_new)

# %%
director_movie_count = (df.groupby("Director").size().sort_values(ascending=False))
director_movie_count
# Out:
# Director
# Steven Spielberg               33
# Unknown                        31
# Clint Eastwood                 31
# Ridley Scott                   29
# Martin Scorsese                29
#                                ..
# Zackary Adler                   1
# Zachary Wigon                   1
# Zach Lipovsky,Adam B. Stein     1
# Zach Helm                       1
# Zach Cregger                    1
# Length: 4364, dtype: int64

# %%
df.columns
# Out:
# Index(['Title', 'Summary', 'Director', 'Writer', 'Main Genres',
#        'Motion Picture Rating', 'runtime_min', 'Release Year',
#        'rating_outof_10', 'no_of_rating', 'Budget', 'Gross worldwide'],
#       dtype='object')

# %%
# since unknown was used after replacing missing value ignore them

director_avg_rating = (df.groupby("Director").agg(avg_rating=('rating_outof_10', 'mean'), rating_count=('rating_outof_10', 'count')))
director_avg_rating = director_avg_rating[director_avg_rating['rating_count'] >= 3].sort_values(by='avg_rating', ascending=False)
director_avg_rating
# Out:
#                   avg_rating  rating_count
# Director
# Michael Crichton    9.000000             4
# Kenny Ortega        9.000000             3
# Stuart Gillard      8.666667             3
# Silvio Amadio       8.333333             3
# Jordan Peele        8.000000             3
# ...                      ...           ...
# Bharat Nalluri      0.666667             3
# Jacques Tourneur    0.666667             3
# Umberto Lenzi       0.666667             3
# Ramin Bahrani       0.666667             3
# Forest Whitaker     0.333333             3
#
# [927 rows x 2 columns]

# %%
df[df["Director"] == 'Akira Kurosawa']['rating_outof_10'].mean()
# Out:
# np.float64(3.625)

# %%
# df.groupby("Title")[df["Director"] == "Michael Crichton"]

df[df["Director"] == "Michael Crichton"][['Title','rating_outof_10']].reset_index().drop(columns='index')
# Out:
#                      Title  rating_outof_10
# 0                Westworld              9.0
# 1  The Great Train Robbery              9.0
# 2                  Runaway              9.0
# 3                     Coma              9.0

# %%
# director popularity

director_popularity = (
    df.groupby('Director')
      .agg(
          total_ratings=('no_of_rating', 'sum'),
          titles=('Title', lambda x: ', '.join(x))
      )
      .sort_values(by='total_ratings', ascending=False)
)
director_popularity[director_popularity.index == 'Christopher Nolan']['titles']
# Out:
# Director
# Christopher Nolan    Oppenheimer, Interstellar, The Dark Knight, In...
# Name: titles, dtype: object

# %%
director_popularity
# Out:
#                                total_ratings  \
# Director
# Christopher Nolan                 15525000.0
# Steven Spielberg                  14198000.0
# Quentin Tarantino                 10633000.0
# Martin Scorsese                   10065900.0
# David Fincher                      8818000.0
# ...                                      ...
# Mark Fischbach                           0.0
# Emmanuelle Pickett                       0.0
# Stephanie Stine,Mike Mitchell            0.0
# Zelda Williams                           0.0
# Adrian Molina                            0.0
#
#                                                                           titles
# Director
# Christopher Nolan              Oppenheimer, Interstellar, The Dark Knight, In...
# Steven Spielberg               Indiana Jones and the Temple of Doom, A.I. Art...
# Quentin Tarantino              Kill Bill: Vol. 2, Once Upon a Time in Hollywo...
# Martin Scorsese                Killers of the Flower Moon, The Wolf of Wall S...
# David Fincher                  The Killer, Alien³, Fight Club, Panic Room, Se...
# ...                                                                          ...
# Mark Fischbach                                                         Iron Lung
# Emmanuelle Pickett                                                     All Souls
# Stephanie Stine,Mike Mitchell                                    Kung Fu Panda 4
# Zelda Williams                                                 Lisa Frankenstein
# Adrian Molina                                                               Elio
#
# [4364 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Title', 'Summary', 'Director', 'Writer', 'Main Genres',
#        'Motion Picture Rating', 'runtime_min', 'Release Year',
#        'rating_outof_10', 'no_of_rating', 'Budget', 'Gross worldwide'],
#       dtype='object')

# %%
director_writer = (
    df[df['Director'] == df['Writer']]          # director is the writer
      .groupby('Director')
      .agg(
          avg_rating=('rating_outof_10', 'mean'),
          titles=('Title', lambda x: ', '.join(x))
      )
      .sort_values(by='avg_rating', ascending=False)
)
director_writer
# Out:
#                   avg_rating              titles
# Director
# Aatish Kapadia           9.0           Khichdi 2
# Jalmari Helander         9.0                Sisu
# James Bird               9.0            Wifelike
# James D'Arcy             9.0       Made in Italy
# Jason Yu                 9.0               Sleep
# ...                      ...                 ...
# Matt Nable               0.0         Transfusion
# Zach Cregger             0.0           Barbarian
# Travis Burgess           0.0             Hayseed
# A.V. Rockwell            0.0  A Thousand and One
# Willard Carroll          0.0    Playing by Heart
#
# [960 rows x 2 columns]

# %%
# director popularity

director_writer = (
    df[df['Director'] == df['Writer']]
      .sort_values(by='rating_outof_10', ascending=False)
      [['Director', 'Title', 'rating_outof_10']]
)
director_writer.rename(columns={'Director': 'Director/Writer'}, inplace=True)
director_writer
# Out:
#                Director/Writer                   Title  rating_outof_10
# 9075                  Jason Yu                   Sleep              9.0
# 4687                Paul Weitz               Moving On              9.0
# 8925         Bobcat Goldthwait    World's Greatest Dad              9.0
# 6405          Andrei Tarkovsky           The Sacrifice              9.0
# 4627            Timo Tjahjanto  The Night Comes for Us              9.0
# ...                        ...                     ...              ...
# 5805            Georgia Oakley               Blue Jean              0.0
# 8715  Àlex Pastor,David Pastor                Carriers              0.0
# 8748        Augustine Frizzell        Never Goin' Back              0.0
# 8761              Edward Burns           She's the One              0.0
# 4782                John Derek                  Bolero              0.0
#
# [1347 rows x 3 columns]

# %%
revenue_rating = (
    df.sort_values(by='rating_outof_10', ascending=False)
    [['Budget','Title','Gross worldwide','rating_outof_10']]
    .set_index('Title')
)
revenue_rating['Gross worldwide']=revenue_rating['Gross worldwide'].map('{:,.0f}'.format)
revenue_rating
# Out:
#                                  Budget Gross worldwide  rating_outof_10
# Title
# Domino                       50000000.0      22,984,628              9.0
# The Creator                  80000000.0     104,181,028              9.0
# The Return                          NaN       8,482,993              9.0
# Wish                        200000000.0      51,276,049              9.0
# Anatomy of a Fall             6200000.0      18,221,260              9.0
# ...                                 ...             ...              ...
# The Escort                          NaN             nan              0.0
# Barbie                      100000000.0   1,441,791,846              0.0
# Blue Beetle                 104000000.0     129,288,072              0.0
# Trolls Band Together                NaN     149,762,759              0.0
# Killers of the Flower Moon  200000000.0     152,178,693              0.0
#
# [9083 rows x 3 columns]

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# 1. Highest rated movies by genre
print("=" * 60)
print("HIGHEST RATED MOVIES BY GENRE")
print("=" * 60)

for genre in genres:
    top_movies = df[df['Main Genres'].str.contains(genre, case=False, na=False)].nlargest(3, 'rating_outof_10')[['Title', 'rating_outof_10', 'Release Year']]
    print(f"\n{genre}:")
    print(top_movies.to_string(index=False))

# 2. Trends over years
print("\n" + "=" * 60)
print("TRENDS OVER YEARS")
print("=" * 60)

trend_data = df.groupby('Release Year').agg({
    'rating_outof_10': 'mean',
    'no_of_rating': 'mean',
    'Budget': 'mean',
    'Gross worldwide': 'mean'
}).reset_index()

plt.figure(figsize=(12, 6))
plt.subplot(2, 2, 1)
plt.plot(trend_data['Release Year'], trend_data['rating_outof_10'], marker='o')
plt.title('Average Rating Over Years')
plt.xlabel('Year')
plt.ylabel('Average Rating')

plt.subplot(2, 2, 2)
plt.plot(trend_data['Release Year'], trend_data['Budget'], marker='o', color='green')
plt.title('Average Budget Over Years')
plt.xlabel('Year')
plt.ylabel('Budget')

plt.subplot(2, 2, 3)
plt.plot(trend_data['Release Year'], trend_data['Gross worldwide'], marker='o', color='red')
plt.title('Average Gross Worldwide Over Years')
plt.xlabel('Year')
plt.ylabel('Gross')

plt.tight_layout()
plt.show()

# 3. Director and actor analysis
print("\n" + "=" * 60)
print("DIRECTOR ANALYSIS")
print("=" * 60)

top_directors = df.groupby('Director').agg({
    'Title': 'count',
    'rating_outof_10': 'mean'
}).rename(columns={'Title': 'Movie Count'}).sort_values('rating_outof_10', ascending=False).head(10)
print(top_directors)

# 4. Rating vs Revenue
print("\n" + "=" * 60)
print("RATING VS REVENUE ANALYSIS")
print("=" * 60)

plt.figure(figsize=(10, 6))
plt.scatter(df_budget['rating_outof_10'], df_budget['Gross worldwide'], alpha=0.5)
plt.xlabel('Rating (out of 10)')
plt.ylabel('Gross Worldwide Revenue')
plt.title('Rating vs Revenue')
correlation = df_budget['rating_outof_10'].corr(df_budget['Gross worldwide'])
plt.text(0.05, 0.95, f'Correlation: {correlation:.3f}', transform=plt.gca().transAxes, verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
plt.tight_layout()
plt.show()
# Out:
# ============================================================
# HIGHEST RATED MOVIES BY GENRE
# ============================================================
#
# Comedy:
#                          Title  rating_outof_10  Release Year
#                           Wish              9.0        2023.0
#                     Dumb Money              9.0        2023.0
# Guardians of the Galaxy Vol. 3              9.0        2023.0
#
# Adventure:
#                          Title  rating_outof_10  Release Year
#                           Wish              9.0        2023.0
#                    The Creator              9.0        2023.0
# Guardians of the Galaxy Vol. 3              9.0        2023.0
#
# Crime:
#                     Title  rating_outof_10  Release Year
# The Marsh King's Daughter              9.0        2023.0
#           The Equalizer 3              9.0        2023.0
#         Anatomy of a Fall              9.0        2023.0
#
# Drama:
#                     Title  rating_outof_10  Release Year
#               The Creator              9.0        2023.0
# The Marsh King's Daughter              9.0        2023.0
#         Anatomy of a Fall              9.0        2023.0
#
# Action:
#                          Title  rating_outof_10  Release Year
#                    The Creator              9.0        2023.0
#                The Equalizer 3              9.0        2023.0
# Guardians of the Galaxy Vol. 3              9.0        2023.0
#
# History:
#                   Title  rating_outof_10  Release Year
# All the President's Men              9.0        1976.0
#          The Woman King              9.0        2022.0
#                   Golda              9.0        2023.0
#
# ============================================================
# TRENDS OVER YEARS
# ============================================================
# ============================================================
# DIRECTOR ANALYSIS
# ============================================================
#                                   Movie Count  rating_outof_10
# Director
# Brian Skiba                                 1              9.0
# Brian Trenchard-Smith                       1              9.0
# Brit McAdams                                1              9.0
# S.K. Dale                                   1              9.0
# Saeed Roustayi                              1              9.0
# Aatish Kapadia                              1              9.0
# Zeno Graton                                 1              9.0
# Adam Deacon                                 1              9.0
# Yûsuke Taki,Morgan Bailey Keaton            1              9.0
# Joel Paul Reisig                            1              9.0
#
# ============================================================
# RATING VS REVENUE ANALYSIS
# ============================================================
